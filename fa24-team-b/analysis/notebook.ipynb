# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df = pd.read_csv('../data/student_addresses.csv',low_memory=False)

# %%
df.head()
# Out:
#                      street_name zip_code level_of_study full_time  \
# 0  11 W Broadway Street  Apt 607    02127             UG        PT
# 1         471 Meridian  Street      02128             UG        PT
# 2         747 Saratoga  Street      02128             UG        PT
# 3              134 Rowe Street      02131             UG        PT
# 4      110 Edgemere  Road  apt 6    02132             UG        PT
#
#   extra_large_unit at_home       university       year
# 0               UK      NH  BayStateCollege  2022-2023
# 1               UK      NH  BayStateCollege  2022-2023
# 2               UK      NH  BayStateCollege  2022-2023
# 3               UK      NH  BayStateCollege  2022-2023
# 4               UK      NH  BayStateCollege  2022-2023

# %% [markdown]
# Preliminary Analysis

# %%
sns.heatmap(pd.crosstab(df['level_of_study'],df['full_time']), annot=True, fmt='d', cmap='viridis')
# Out:
# <Axes: xlabel='full_time', ylabel='level_of_study'>
