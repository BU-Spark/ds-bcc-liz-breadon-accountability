# %%
import geopandas as gpd

# %%
import pandas as pd

# %%
shapefile = gpd.read_file("fa24-team-a//RawData//Districts//CityCouncilDistricts_2024.shp")
# Out:
# ---------------------------------------------------------------------------
# DataSourceError                           Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 shapefile = gpd.read_file("..//..//fa24-team-a//RawData//Districts//CityCouncilDistricts_2024.shp")
#
# File c:\Users\adity\AppData\Local\Programs\Python\Python312\Lib\site-packages\geopandas\io\file.py:294, in _read_file(filename, bbox, mask, columns, rows, engine, **kwargs)
#     291             from_bytes = True
#     293 if engine == "pyogrio":
# --> 294     return _read_file_pyogrio(
#     295         filename, bbox=bbox, mask=mask, columns=columns, rows=rows, **kwargs
#     296     )
#     298 elif engine == "fiona":
#     299     if pd.api.types.is_file_like(filename):
#
# File c:\Users\adity\AppData\Local\Programs\Python\Python312\Lib\site-packages\geopandas\io\file.py:547, in _read_file_pyogrio(path_or_bytes, bbox, mask, rows, **kwargs)
#     538     warnings.warn(
# ...

# %%
shapefile
# Out:
#      LONGNAME SHORTNAME  DISTRICT                 Councilor  \
# 0  District 1        D1         1          Gabriela Coletta
# 1  District 2        D2         2                  Ed Flynn
# 2  District 3        D3         3           John Fitzgerald
# 3  District 4        D4         4             Brian Worrell
# 4  District 5        D5         5             Enrique Pepén
# 5  District 6        D6         6            Benjamin Weber
# 6  District 7        D7         7  Tania Fernandes Anderson
# 7  District 8        D8         8             Sharon Durkan
# 8  District 9        D9         9               Liz Breadon
#
#                                            Webpage                     Bio  \
# 0  https://www.boston.gov/departments/city-council  https://bit.ly/3Nd4A9O
# 1  https://www.boston.gov/departments/city-council  https://bit.ly/2DRQt6L
# 2  https://www.boston.gov/departments/city-council  https://bit.ly/3RPZZ1I
# ...

# %%
import matplotlib.pyplot as plt

# %%
fig,ax =plt.subplots(figsize=(12,10))
shapefile.plot(ax=ax,column="DISTRICT", cmap="Reds")
ax.legend()
# Out:
# C:\Users\adity\AppData\Local\Temp\ipykernel_26516\1168506916.py:3: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   ax.legend()

# %%
# !pip install contextily
# Out:
# ...
#    ---------------------------------------- 0.0/25.3 MB ? eta -:--:--
#    - -------------------------------------- 1.0/25.3 MB 5.0 MB/s eta 0:00:05
#    ---- ----------------------------------- 2.6/25.3 MB 6.6 MB/s eta 0:00:04
#    ----- ---------------------------------- 3.7/25.3 MB 6.4 MB/s eta 0:00:04
#    ------ --------------------------------- 4.2/25.3 MB 5.5 MB/s eta 0:00:04
#    ------- -------------------------------- 4.5/25.3 MB 5.0 MB/s eta 0:00:05
#    ------- -------------------------------- 4.7/25.3 MB 4.4 MB/s eta 0:00:05
#    -------- ------------------------------- 5.2/25.3 MB 3.8 MB/s eta 0:00:06
#    --------- ------------------------------ 5.8/25.3 MB 3.6 MB/s eta 0:00:06
#    --------- ------------------------------ 6.3/25.3 MB 3.4 MB/s eta 0:00:06
#    ---------- ----------------------------- 6.8/25.3 MB 3.4 MB/s eta 0:00:06
#    ------------ --------------------------- 8.1/25.3 MB 3.5 MB/s eta 0:00:05
# ...

# %%
import contextily as cx

# %%
df2 = pd.read_csv("student_housing_percentage_by_district_2024.csv")

# %%
districts = districts.merge(df2, on='DISTRICT')

# %% [markdown]
# districts

# %%
districts = shapefile.to_crs(epsg=3857)

# %%
fig, ax = plt.subplots(1, 1, figsize=(15, 15))
districts.plot(column='Num_Students', cmap='RdBu_r', legend=True, ax=ax, alpha=0.6,legend_kwds={'shrink': 0.3})
districts.boundary.plot(ax=ax, linewidth=0.5, edgecolor='black')
# Add the street map background (tiles come from OpenStreetMap by default)
cx.add_basemap(ax, source=cx.providers.CartoDB.Voyager,zoom=12)

for idx, row in districts.iterrows():
    centroid = row['geometry'].centroid  # Get the centroid of each district
    plt.annotate(text=row['DISTRICT'], xy=(centroid.x, centroid.y), xytext=(3, 3),
                 textcoords="offset points", fontsize=12, color='black', weight='bold')
plt.savefig('district_population_map.png', dpi=300)
# Show the plot
plt.title('District Student Population 2024')
plt.show()
