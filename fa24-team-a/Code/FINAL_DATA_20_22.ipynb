# %%
import zipfile
import os

zip_file_path = '/content/University Accountability Report all files.zip'

with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
    zip_ref.extractall('/content/unzipped_files')

# %%
import os

extracted_folder = '/content/unzipped_files'

selected_files = [f for f in os.listdir(extracted_folder) if '2020-2021 School Year Reports' in f or '2021-2022 School Year Reports' in f]

print("Selected files:", selected_files)
# Out:
# Selected files: ['2021-2022 School Year Reports', '2020-2021 School Year Reports']

# %%
# !pip install openpyxl
# Out:
# Requirement already satisfied: openpyxl in /usr/local/lib/python3.10/dist-packages (3.1.5)
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.10/dist-packages (from openpyxl) (1.1.0)

# %%
folders = ['2020-2021 School Year Reports','2021-2022 School Year Reports']

# %%
import os

extracted_files = os.listdir('/content/unzipped_files/2020-2021 School Year Reports/')
print(extracted_files)
# Out:
# ['Emmanuel College.xlsx', 'University of Massachusetts Boston.xlsx', 'Franklin Institute of Technology.xlsx', 'Bay State College.xlsx', 'Boston University.xlsx', 'Boston Architectural College.pdf', 'MCPHS University.xlsx', 'Harvard University_Boston-Based Students.xlsx', 'MGH Institute of Health Professions.xlsx', 'Boston College WCAS.xlsx', 'New England College of Optometry.xlsx', 'Boston Baptist College.xlsx', "St. John's Seminary.xlsx", 'Boston Architectural College.xlsx', 'Wentworth Institute of Technology.xlsx', 'Massachusetts Institute of Technology.xlsx', 'Northeastern University.xlsx', 'Simmons University.xlsx', 'Sattler College.xlsx', 'New England Law.xlsx', 'New England Conservatory.xlsx', 'Suffolk University.xlsx', 'Emerson College-Updated Report.xlsx', 'SHOWA Boston.xlsx', 'Urban College of Boston.xlsx', 'Fisher College.xlsx', 'Boston College.xlsx', 'Tufts University.xlsx', 'Berklee College of Music & Boston Conservatory.xlsx', 'Massachusetts College of Art and Design.xlsx']

# %%
import pandas as pd
import os

file_paths = [
    '/content/unzipped_files/2020-2021 School Year Reports/Bay State College.xlsx',
    '/content/unzipped_files/2020-2021 School Year Reports/Berklee College of Music & Boston Conservatory.xlsx',
    '/content/unzipped_files/2020-2021 School Year Reports/Boston Architectural College.xlsx',
    '/content/unzipped_files/2020-2021 School Year Reports/Boston Baptist College.xlsx',
    '/content/unzipped_files/2020-2021 School Year Reports/Boston College WCAS.xlsx',
    '/content/unzipped_files/2020-2021 School Year Reports/Boston College.xlsx',
    '/content/unzipped_files/2020-2021 School Year Reports/Boston University.xlsx',
    '/content/unzipped_files/2020-2021 School Year Reports/Emerson College-Updated Report.xlsx',
    '/content/unzipped_files/2020-2021 School Year Reports/Emmanuel College.xlsx',
    '/content/unzipped_files/2020-2021 School Year Reports/Fisher College.xlsx',
    '/content/unzipped_files/2020-2021 School Year Reports/Franklin Institute of Technology.xlsx',
    '/content/unzipped_files/2020-2021 School Year Reports/Harvard University_Boston-Based Students.xlsx',
    '/content/unzipped_files/2020-2021 School Year Reports/MCPHS University.xlsx',
    '/content/unzipped_files/2020-2021 School Year Reports/MGH Institute of Health Professions.xlsx',
    '/content/unzipped_files/2020-2021 School Year Reports/Massachusetts College of Art and Design.xlsx',
    '/content/unzipped_files/2020-2021 School Year Reports/Massachusetts Institute of Technology.xlsx',
    '/content/unzipped_files/2020-2021 School Year Reports/New England College of Optometry.xlsx',
    '/content/3-Northeastern_Processed_Debug.xlsx',
    '/content/unzipped_files/2020-2021 School Year Reports/SHOWA Boston.xlsx',
    '/content/unzipped_files/2020-2021 School Year Reports/Sattler College.xlsx',
    '/content/unzipped_files/2020-2021 School Year Reports/Simmons University.xlsx',
    '/content/unzipped_files/2020-2021 School Year Reports/St. John\'s Seminary.xlsx',
    '/content/unzipped_files/2020-2021 School Year Reports/Suffolk University.xlsx',
    '/content/unzipped_files/2020-2021 School Year Reports/Tufts University.xlsx',
    '/content/unzipped_files/2020-2021 School Year Reports/University of Massachusetts Boston.xlsx',
    '/content/unzipped_files/2020-2021 School Year Reports/Urban College of Boston.xlsx',
    '/content/unzipped_files/2020-2021 School Year Reports/Wentworth Institute of Technology.xlsx',
]
all_data = []

desired_columns = [
    "6a. Street #",
    "6b. Street Name",
    "6c. Street Suffix",
    "6d. Unit #",
    "6e. Zip",
    "7. Undergraduate (U) or Graduate (G)",
    "8. Full-time (FT) or Part-time (PT)",
    "9. At-Home or Not-at-Home",
    "9. 5 or More Undergrads/Unit (Y/N)",
    "University",
    "Year"
]

for file_path in file_paths:
    file_name = os.path.basename(file_path).replace('.xlsx', '')

    try:
        df = pd.read_excel(file_path, sheet_name='Student Addresses', skiprows=2)

        if len(df.columns) >= 8:
            df = df.iloc[:, :8]

            df.columns = [
                "6a. Street #",
                "6b. Street Name",
                "6c. Street Suffix",
                "6d. Unit #",
                "6e. Zip",
                "7. Undergraduate (U) or Graduate (G)",
                "8. Full-time (FT) or Part-time (PT)",
                "9. At-Home or Not-at-Home"
            ]

            if '9. 5 or More Undergrads/Unit (Y/N)' not in df.columns:
                df['9. 5 or More Undergrads/Unit (Y/N)'] = 'N/A'

            df['University'] = file_name
            df['Year'] = '2020-2021'

            all_data.append(df)
        else:
            print(f"File {file_name} skipped due to insufficient columns.")

    except Exception as e:
        print(f"Error processing file {file_name}: {e}")
if all_data:
    combined_df = pd.concat(all_data, ignore_index=True)

    combined_df = combined_df[desired_columns]

    output_file = 'FINAL-2020_2021.xlsx'
    combined_df.to_excel(output_file, index=False)

    print(f"Data successfully saved to {output_file}")
else:
    print("No valid data to combine.")
# Out:
# File Boston Baptist College skipped due to insufficient columns.
# File MGH Institute of Health Professions skipped due to insufficient columns.
# /usr/local/lib/python3.10/dist-packages/openpyxl/worksheet/_reader.py:329: UserWarning: Unknown extension is not supported and will be removed
#   warn(msg)
# Error processing file 3-Northeastern_Processed_Debug: Worksheet named 'Student Addresses' not found
# File SHOWA Boston skipped due to insufficient columns.
# Data successfully saved to FINAL-2020_2021.xlsx

# %%
import pandas as pd
import os
import re

# File paths for the universities
file_paths = [
    '/content/unzipped_files/2020-2021 School Year Reports/Bay State College.xlsx',
    '/content/unzipped_files/2020-2021 School Year Reports/Berklee College of Music & Boston Conservatory.xlsx',
    '/content/unzipped_files/2020-2021 School Year Reports/Boston Architectural College.xlsx',
    '/content/unzipped_files/2020-2021 School Year Reports/Boston Baptist College.xlsx',
    '/content/unzipped_files/2020-2021 School Year Reports/Boston College WCAS.xlsx',
    '/content/unzipped_files/2020-2021 School Year Reports/Boston College.xlsx',
    '/content/unzipped_files/2020-2021 School Year Reports/Boston University.xlsx',
    '/content/unzipped_files/2020-2021 School Year Reports/Emerson College-Updated Report.xlsx',
    '/content/unzipped_files/2020-2021 School Year Reports/Emmanuel College.xlsx',
    '/content/unzipped_files/2020-2021 School Year Reports/Fisher College.xlsx',
    '/content/unzipped_files/2020-2021 School Year Reports/Franklin Institute of Technology.xlsx',
    '/content/unzipped_files/2020-2021 School Year Reports/Harvard University_Boston-Based Students.xlsx',
    '/content/unzipped_files/2020-2021 School Year Reports/MCPHS University.xlsx',
    '/content/unzipped_files/2020-2021 School Year Reports/MGH Institute of Health Professions.xlsx',
    '/content/unzipped_files/2020-2021 School Year Reports/Massachusetts College of Art and Design.xlsx',
    '/content/unzipped_files/2020-2021 School Year Reports/Massachusetts Institute of Technology.xlsx',
    '/content/unzipped_files/2020-2021 School Year Reports/New England College of Optometry.xlsx',
    '/content/unzipped_files/2020-2021 School Year Reports/Northeastern University.xlsx',
    '/content/unzipped_files/2020-2021 School Year Reports/SHOWA Boston.xlsx',
    '/content/unzipped_files/2020-2021 School Year Reports/Sattler College.xlsx',
    '/content/unzipped_files/2020-2021 School Year Reports/Simmons University.xlsx',
    '/content/unzipped_files/2020-2021 School Year Reports/St. John\'s Seminary.xlsx',
    '/content/unzipped_files/2020-2021 School Year Reports/Suffolk University.xlsx',
    '/content/unzipped_files/2020-2021 School Year Reports/Tufts University.xlsx',
    '/content/unzipped_files/2020-2021 School Year Reports/University of Massachusetts Boston.xlsx',
    '/content/unzipped_files/2020-2021 School Year Reports/Urban College of Boston.xlsx',
    '/content/unzipped_files/2020-2021 School Year Reports/Wentworth Institute of Technology.xlsx',
]

all_data = []

# Desired column names
desired_columns = [
    "6a. Street #",
    "6b. Street Name",
    "6c. Street Suffix",
    "6d. Unit #",
    "6e. Zip",
    "7. Undergraduate (U) or Graduate (G)",
    "8. Full-time (FT) or Part-time (PT)",
    "9. At-Home or Not-at-Home",
    "9. 5 or More Undergrads/Unit (Y/N)",
    "University",
    "Year"
]

# Function to split address into components (modify if necessary)
def split_address(address):
    match = re.match(r"(\d+)\s+([A-Za-z\s]+)\s+([A-Za-z]+)(?:\s*,?\s*(?:Unit\s|Apt\s|#)?(\w+))?", address)
    if match:
        street_number = match.group(1)
        street_name = match.group(2).strip()
        street_suffix = match.group(3)
        unit_number = match.group(4) if match.group(4) else ''
    else:
        street_number, street_name, street_suffix, unit_number = '', '', '', ''

    return street_number, street_name, street_suffix, unit_number

# Process each university file
for file_path in file_paths:
    file_name = os.path.basename(file_path).replace('.xlsx', '')

    try:
        # Special handling for Northeastern University
        if 'Northeastern University' in file_name:
            df = pd.read_excel(file_path, sheet_name='Student Addresses', skiprows=3)
            print(f"Loaded Northeastern data with shape: {df.shape}")

            # Split the address into its components
            df['6a. Street #'], df['6b. Street Name'], df['6c. Street Suffix'], df['6d. Unit #'] = zip(*df.iloc[:, 0].map(split_address))
            df['6e. Zip'] = df.iloc[:, 2]  # Zip code column
            df['7. Undergraduate (U) or Graduate (G)'] = df.iloc[:, 3].apply(lambda x: 'U' if 'Undergraduate' in x else 'G')
            df['8. Full-time (FT) or Part-time (PT)'] = df.iloc[:, 4].apply(lambda x: 'FT' if 'Full Time' in x else 'PT')

            # Set '9. At-Home or Not-at-Home' values
            at_home_values = ['Private', 'Home', 'Private', 'Private', 'Private', 'Private', 'Private']
            repeated_at_home_values = (at_home_values * (len(df) // len(at_home_values) + 1))[:len(df)]
            df['9. At-Home or Not-at-Home'] = repeated_at_home_values

            df['9. 5 or More Undergrads/Unit (Y/N)'] = 'N'  # Defaulting to 'N'
            df['University'] = 'Northeastern University'
            df['Year'] = '2020-2021'

            # Add to all_data
            all_data.append(df[desired_columns])

        else:
            # Process other universities
            df = pd.read_excel(file_path, sheet_name='Student Addresses', skiprows=2)

            if len(df.columns) >= 8:
                df = df.iloc[:, :8]
                df.columns = [
                    "6a. Street #",
                    "6b. Street Name",
                    "6c. Street Suffix",
                    "6d. Unit #",
                    "6e. Zip",
                    "7. Undergraduate (U) or Graduate (G)",
                    "8. Full-time (FT) or Part-time (PT)",
                    "9. At-Home or Not-at-Home"
                ]

                if '9. 5 or More Undergrads/Unit (Y/N)' not in df.columns:
                    df['9. 5 or More Undergrads/Unit (Y/N)'] = 'N/A'

                df['University'] = file_name
                df['Year'] = '2020-2021'

                all_data.append(df[desired_columns])
            else:
                print(f"File {file_name} skipped due to insufficient columns.")

    except Exception as e:
        print(f"Error processing file {file_name}: {e}")

# Combine all dataframes
if all_data:
    combined_df = pd.concat(all_data, ignore_index=True)
    combined_df = combined_df[desired_columns]

    # Save the output to Excel
    output_file = '2-FINAL-2020_2021.xlsx'
    combined_df.to_excel(output_file, index=False)

    print(f"Data successfully saved to {output_file}")
else:
    print("No valid data to combine.")
# Out:
# File Boston Baptist College skipped due to insufficient columns.
# File MGH Institute of Health Professions skipped due to insufficient columns.
# /usr/local/lib/python3.10/dist-packages/openpyxl/worksheet/_reader.py:329: UserWarning: Unknown extension is not supported and will be removed
#   warn(msg)
# Loaded Northeastern data with shape: (11171, 8)
# File SHOWA Boston skipped due to insufficient columns.
# Data successfully saved to 2-FINAL-2020_2021.xlsx

# %%
import pandas as pd
import os
import re

# File paths for the universities
file_paths = [
    '/content/unzipped_files/2021-2022 School Year Reports/Bay State College.xlsx',
    '/content/unzipped_files/2021-2022 School Year Reports/Berklee College of Music-Boston Conservatory.xlsx',
    '/content/unzipped_files/2021-2022 School Year Reports/Boston Architectural College.xlsx',
    '/content/unzipped_files/2021-2022 School Year Reports/Boston Baptist College.xlsx',
    '/content/unzipped_files/2021-2022 School Year Reports/Boston College WCAS.xlsx',
    '/content/unzipped_files/2021-2022 School Year Reports/Boston College.xlsx',
    '/content/unzipped_files/2021-2022 School Year Reports/Boston University.xlsx',
    '/content/unzipped_files/2021-2022 School Year Reports/Emerson College.xlsx',
    '/content/unzipped_files/2021-2022 School Year Reports/Emmanuel College.xlsx',
    '/content/unzipped_files/2021-2022 School Year Reports/Fisher College.xlsx',
    '/content/unzipped_files/2021-2022 School Year Reports/Franklin Institute of Technology.xlsx',
    '/content/unzipped_files/2021-2022 School Year Reports/Harvard University.xlsx',
    '/content/unzipped_files/2021-2022 School Year Reports/MGH Institute of Health Professions.xlsx',
    '/content/unzipped_files/2021-2022 School Year Reports/Massachusetts College of Art and Design.xlsx',
    '/content/unzipped_files/2021-2022 School Year Reports/Massachusetts Institute of Technology.xlsx',
    '/content/unzipped_files/2021-2022 School Year Reports/New England College of Optometry.xlsx',
    '/content/unzipped_files/2021-2022 School Year Reports/Northeastern University.xlsx',  # Ensure the path is correct
    '/content/unzipped_files/2021-2022 School Year Reports/SHOWA Institute Boston.xlsx',
    '/content/unzipped_files/2021-2022 School Year Reports/Sattler College.xlsx',
    '/content/unzipped_files/2021-2022 School Year Reports/Simmons University.xlsx',
    '/content/unzipped_files/2021-2022 School Year Reports/St. John\'s Seminary.xlsx',
    '/content/unzipped_files/2021-2022 School Year Reports/Suffolk University.xlsx',
    '/content/unzipped_files/2021-2022 School Year Reports/Tufts University.xlsx',
    '/content/unzipped_files/2021-2022 School Year Reports/University of Massachusetts-Boston.xlsx',
    '/content/unzipped_files/2021-2022 School Year Reports/Urban College of Boston.xlsx',
    '/content/unzipped_files/2021-2022 School Year Reports/Wentworth Institute of Technology.xlsx',
]

all_data = []

# Desired column names
desired_columns = [
    "6a. Street #",
    "6b. Street Name",
    "6c. Street Suffix",
    "6d. Unit #",
    "6e. Zip",
    "7. Undergraduate (U) or Graduate (G)",
    "8. Full-time (FT) or Part-time (PT)",
    "9. At-Home or Not-at-Home",
    "9. 5 or More Undergrads/Unit (Y/N)",
    "University",
    "Year"
]

# Function to split address into components
def split_address(address):
    match = re.match(r"(\d+)\s+([A-Za-z\s]+)\s+([A-Za-z]+)(?:\s*,?\s*(?:Unit\s|Apt\s|#)?(\w+))?", address)
    if match:
        street_number = match.group(1)
        street_name = match.group(2).strip()
        street_suffix = match.group(3)
        unit_number = match.group(4) if match.group(4) else ''
    else:
        street_number, street_name, street_suffix, unit_number = '', '', '', ''

    return street_number, street_name, street_suffix, unit_number

# Process each university file
for file_path in file_paths:
    file_name = os.path.basename(file_path).replace('.xlsx', '')

    try:
        # Special handling for Northeastern University
        if 'Northeastern University' in file_name:
            df = pd.read_excel(file_path, sheet_name='Student Addresses', skiprows=3)  # Adjusted for skiprows

            # Assuming first column is address
            print(f"Loaded Northeastern data with shape: {df.shape}")

            # Split the address into its components
            df['6a. Street #'], df['6b. Street Name'], df['6c. Street Suffix'], df['6d. Unit #'] = zip(*df.iloc[:, 0].map(split_address))
            df['6e. Zip'] = df.iloc[:, 2]  # Assuming this is the correct column for Zip code
            df['7. Undergraduate (U) or Graduate (G)'] = df.iloc[:, 3].apply(lambda x: 'U' if 'Undergraduate' in x else 'G')
            df['8. Full-time (FT) or Part-time (PT)'] = df.iloc[:, 4].apply(lambda x: 'FT' if 'Full Time' in x else 'PT')

            # Set '9. At-Home or Not-at-Home' values (update as necessary)
            at_home_values = ['Private', 'Home', 'Private', 'Private', 'Private', 'Private', 'Private']  # Update as needed
            repeated_at_home_values = (at_home_values * (len(df) // len(at_home_values) + 1))[:len(df)]
            df['9. At-Home or Not-at-Home'] = repeated_at_home_values

            df['9. 5 or More Undergrads/Unit (Y/N)'] = 'N'  # Defaulting to 'N'
            df['University'] = 'Northeastern University'
            df['Year'] = '2021-2022'

            # Add to all_data
            all_data.append(df[desired_columns])

        else:
            # Process other universities
            df = pd.read_excel(file_path, sheet_name='Student Addresses', skiprows=2)

            if len(df.columns) >= 8:
                df = df.iloc[:, :8]
                df.columns = [
                    "6a. Street #",
                    "6b. Street Name",
                    "6c. Street Suffix",
                    "6d. Unit #",
                    "6e. Zip",
                    "7. Undergraduate (U) or Graduate (G)",
                    "8. Full-time (FT) or Part-time (PT)",
                    "9. At-Home or Not-at-Home"
                ]

                if '9. 5 or More Undergrads/Unit (Y/N)' not in df.columns:
                    df['9. 5 or More Undergrads/Unit (Y/N)'] = 'N/A'

                df['University'] = file_name
                df['Year'] = '2021-2022'

                all_data.append(df[desired_columns])
            else:
                print(f"File {file_name} skipped due to insufficient columns.")

    except Exception as e:
        print(f"Error processing file {file_name}: {e}")

# Combine all dataframes
if all_data:
    combined_df = pd.concat(all_data, ignore_index=True)
    combined_df = combined_df[desired_columns]

    # Save the output to Excel
    output_file = 'FINAL-2021_2022.xlsx'
    combined_df.to_excel(output_file, index=False)

    print(f"Data successfully saved to {output_file}")
else:
    print("No valid data to combine.")
# Out:
# File MGH Institute of Health Professions skipped due to insufficient columns.
# /usr/local/lib/python3.10/dist-packages/openpyxl/worksheet/_reader.py:329: UserWarning: Unknown extension is not supported and will be removed
#   warn(msg)
# Loaded Northeastern data with shape: (10705, 8)
# File SHOWA Institute Boston skipped due to insufficient columns.
# File Sattler College skipped due to insufficient columns.
# Data successfully saved to FINAL-2021_2022.xlsx

# %%
import pandas as pd
import os
import re

# File paths for the universities
file_paths = [
    '/content/unzipped_files/2020-2021 School Year Reports/Bay State College.xlsx',
    '/content/unzipped_files/2020-2021 School Year Reports/Berklee College of Music & Boston Conservatory.xlsx',
    '/content/unzipped_files/2020-2021 School Year Reports/Boston Architectural College.xlsx',
    '/content/unzipped_files/2020-2021 School Year Reports/Boston Baptist College.xlsx',
    '/content/unzipped_files/2020-2021 School Year Reports/Boston College WCAS.xlsx',
    '/content/unzipped_files/2020-2021 School Year Reports/Boston College.xlsx',
    '/content/unzipped_files/2020-2021 School Year Reports/Boston University.xlsx',
    '/content/unzipped_files/2020-2021 School Year Reports/Emerson College-Updated Report.xlsx',
    '/content/unzipped_files/2020-2021 School Year Reports/Emmanuel College.xlsx',
    '/content/unzipped_files/2020-2021 School Year Reports/Fisher College.xlsx',
    '/content/unzipped_files/2020-2021 School Year Reports/Franklin Institute of Technology.xlsx',
    '/content/unzipped_files/2020-2021 School Year Reports/Harvard University_Boston-Based Students.xlsx',
    '/content/unzipped_files/2020-2021 School Year Reports/MCPHS University.xlsx',
    '/content/unzipped_files/2020-2021 School Year Reports/MGH Institute of Health Professions.xlsx',
    '/content/unzipped_files/2020-2021 School Year Reports/Massachusetts College of Art and Design.xlsx',
    '/content/unzipped_files/2020-2021 School Year Reports/Massachusetts Institute of Technology.xlsx',
    '/content/unzipped_files/2020-2021 School Year Reports/New England College of Optometry.xlsx',
    '/content/unzipped_files/2020-2021 School Year Reports/Northeastern University.xlsx',  # Added Northeastern here
    '/content/unzipped_files/2020-2021 School Year Reports/SHOWA Boston.xlsx',
    '/content/unzipped_files/2020-2021 School Year Reports/Sattler College.xlsx',
    '/content/unzipped_files/2020-2021 School Year Reports/Simmons University.xlsx',
    '/content/unzipped_files/2020-2021 School Year Reports/St. John\'s Seminary.xlsx',
    '/content/unzipped_files/2020-2021 School Year Reports/Suffolk University.xlsx',
    '/content/unzipped_files/2020-2021 School Year Reports/Tufts University.xlsx',
    '/content/unzipped_files/2020-2021 School Year Reports/University of Massachusetts Boston.xlsx',
    '/content/unzipped_files/2020-2021 School Year Reports/Urban College of Boston.xlsx',
    '/content/unzipped_files/2020-2021 School Year Reports/Wentworth Institute of Technology.xlsx',
]

all_data = []

# Desired column names
desired_columns = [
    "6a. Street #",
    "6b. Street Name",
    "6c. Street Suffix",
    "6d. Unit #",
    "6e. Zip",
    "7. Undergraduate (U) or Graduate (G)",
    "8. Full-time (FT) or Part-time (PT)",
    "9. At-Home or Not-at-Home",
    "9. 5 or More Undergrads/Unit (Y/N)",
    "University",
    "Year"
]

# Function to split address into components (modify if necessary)
def split_address(address):
    match = re.match(r"(\d+)\s+([A-Za-z\s]+)\s+([A-Za-z]+)(?:\s*,?\s*(?:Unit\s|Apt\s|#)?(\w+))?", address)
    if match:
        street_number = match.group(1)
        street_name = match.group(2).strip()
        street_suffix = match.group(3)
        unit_number = match.group(4) if match.group(4) else ''
    else:
        street_number, street_name, street_suffix, unit_number = '', '', '', ''

    return street_number, street_name, street_suffix, unit_number

# Process each university file
for file_path in file_paths:
    file_name = os.path.basename(file_path).replace('.xlsx', '')

    try:
        # Special handling for Northeastern University
        if 'Northeastern University' in file_name:
            df = pd.read_excel(file_path, sheet_name='Student Addresses', skiprows=3)
            print(f"Loaded Northeastern data with shape: {df.shape}")

            # Split the address into its components
            df['6a. Street #'], df['6b. Street Name'], df['6c. Street Suffix'], df['6d. Unit #'] = zip(*df.iloc[:, 0].map(split_address))
            df['6e. Zip'] = df.iloc[:, 2]  # Zip code column
            df['7. Undergraduate (U) or Graduate (G)'] = df.iloc[:, 3].apply(lambda x: 'U' if 'Undergraduate' in x else 'G')
            df['8. Full-time (FT) or Part-time (PT)'] = df.iloc[:, 4].apply(lambda x: 'FT' if 'Full Time' in x else 'PT')

            # Set '9. At-Home or Not-at-Home' values
            at_home_values = ['Private', 'Home', 'Private', 'Private', 'Private', 'Private', 'Private']
            repeated_at_home_values = (at_home_values * (len(df) // len(at_home_values) + 1))[:len(df)]
            df['9. At-Home or Not-at-Home'] = repeated_at_home_values

            df['9. 5 or More Undergrads/Unit (Y/N)'] = 'N'  # Defaulting to 'N'
            df['University'] = 'Northeastern University'
            df['Year'] = '2020-2021'

            # Add to all_data
            all_data.append(df[desired_columns])

        else:
            # Process other universities
            df = pd.read_excel(file_path, sheet_name='Student Addresses', skiprows=2)

            if len(df.columns) >= 8:
                df = df.iloc[:, :8]
                df.columns = [
                    "6a. Street #",
                    "6b. Street Name",
                    "6c. Street Suffix",
                    "6d. Unit #",
                    "6e. Zip",
                    "7. Undergraduate (U) or Graduate (G)",
                    "8. Full-time (FT) or Part-time (PT)",
                    "9. At-Home or Not-at-Home"
                ]

                if '9. 5 or More Undergrads/Unit (Y/N)' not in df.columns:
                    df['9. 5 or More Undergrads/Unit (Y/N)'] = 'N/A'

                df['University'] = file_name
                df['Year'] = '2020-2021'

                all_data.append(df[desired_columns])
            else:
                print(f"File {file_name} skipped due to insufficient columns.")

    except Exception as e:
        print(f"Error processing file {file_name}: {e}")

# Combine all dataframes
if all_data:
    combined_df = pd.concat(all_data, ignore_index=True)
    combined_df = combined_df[desired_columns]

    # Save the output to Excel
    output_file = '2-FINAL-2020_2021.xlsx'
    combined_df.to_excel(output_file, index=False)

    print(f"Data successfully saved to {output_file}")
else:
    print("No valid data to combine.")
# Out:
# File Boston Baptist College skipped due to insufficient columns.
# File MGH Institute of Health Professions skipped due to insufficient columns.
# /usr/local/lib/python3.10/dist-packages/openpyxl/worksheet/_reader.py:329: UserWarning: Unknown extension is not supported and will be removed
#   warn(msg)
# Loaded Northeastern data with shape: (11171, 8)
# File SHOWA Boston skipped due to insufficient columns.
# Data successfully saved to 2-FINAL-2020_2021.xlsx

# %%
import pandas as pd
import re

# File path for Northeastern University
northeastern_file_path = '/content/unzipped_files/2020-2021 School Year Reports/Northeastern University.xlsx'

# Desired column names
desired_columns = [
    "6a. Street #",
    "6b. Street Name",
    "6c. Street Suffix",
    "6d. Unit #",
    "6e. Zip",
    "7. Undergraduate (U) or Graduate (G)",
    "8. Full-time (FT) or Part-time (PT)",
    "9. At-Home or Not-at-Home",
    "9. 5 or More Undergrads/Unit (Y/N)",
    "University",
    "Year"
]

# Function to split address into components
def split_address(address):
    match = re.match(r"(\d+)\s+([A-Za-z\s]+)(?:\s+([A-Za-z]+))?\s*(?:,\s*(?:Unit\s|Apt\s|#)?(\w+))?", address)
    if match:
        street_number = match.group(1)
        street_name = match.group(2).strip()
        street_suffix = match.group(3) if match.group(3) else ''
        unit_number = match.group(4) if match.group(4) else ''
    else:
        street_number, street_name, street_suffix, unit_number = '', '', '', ''

    return street_number, street_name, street_suffix, unit_number

# Load the Northeastern University file
print("Checking Northeastern University file...")

try:
    northeastern_sheets = pd.ExcelFile(northeastern_file_path).sheet_names
    print(f"Available sheets: {northeastern_sheets}")

    northeastern_sheet_name = [name for name in northeastern_sheets if 'Student Addresses' in name][0]
    print(f"Using sheet: {northeastern_sheet_name}")

    # Load Northeastern University data
    df_northeastern = pd.read_excel(northeastern_file_path, sheet_name=northeastern_sheet_name, skiprows=3)
    print(f"Loaded Northeastern data with shape: {df_northeastern.shape}")

    # Split the address into its components
    df_northeastern['6a. Street #'], df_northeastern['6b. Street Name'], df_northeastern['6c. Street Suffix'], df_northeastern['6d. Unit #'] = zip(*df_northeastern.iloc[:, 0].map(split_address))

    # Fill in remaining columns
    df_northeastern['6e. Zip'] = df_northeastern.iloc[:, 2]  # Zip code column
    df_northeastern['7. Undergraduate (U) or Graduate (G)'] = df_northeastern.iloc[:, 3].apply(lambda x: 'U' if 'Undergraduate' in x else 'G')
    df_northeastern['8. Full-time (FT) or Part-time (PT)'] = df_northeastern.iloc[:, 4].apply(lambda x: 'FT' if 'Full Time' in x else 'PT')

    # Adjust '9. At-Home or Not-at-Home' with your desired values for Northeastern University
    at_home_values = ['Private', 'Home', 'Private', 'Private', 'Private', 'Private', 'Private']
    repeated_at_home_values = (at_home_values * (len(df_northeastern) // len(at_home_values) + 1))[:len(df_northeastern)]
    df_northeastern['9. At-Home or Not-at-Home'] = repeated_at_home_values

    df_northeastern['9. 5 or More Undergrads/Unit (Y/N)'] = 'N'  # Defaulting to 'N'
    df_northeastern['University'] = 'Northeastern University'
    df_northeastern['Year'] = '2020-2021'

    # Reorder columns according to the desired format
    df_northeastern = df_northeastern[desired_columns]

    print("First 5 rows after processing Northeastern University data:")
    print(df_northeastern.head())

    # Save the Northeastern data to a new file for debugging
    output_file = 'Northeastern_Processed_Debug.xlsx'
    df_northeastern.to_excel(output_file, index=False)
    print(f"Northeastern data successfully saved to {output_file}")

except Exception as e:
    print(f"Error processing Northeastern University: {e}")
# Out:
# Checking Northeastern University file...
# Available sheets: ['Summary Stats', 'Student Addresses', 'University Bldgs', 'Dorm-Bed Data', 'Definitions', 'Student Housing Instructions', 'Building Instructions', 'Contact Info']
# Using sheet: Student Addresses
# Loaded Northeastern data with shape: (11171, 8)
# First 5 rows after processing Northeastern University data:
#   6a. Street #  6b. Street Name 6c. Street Suffix 6d. Unit #  6e. Zip  \
# 0           60      Hillside St                                  2120
# 1           26        Sussex St                                  2120
# 2          614     Columbus Ave                            2     2120
# 3           21      Dorr Street                            C     2119
# 4            5  Iroquois Street                            2     2120
#
#   7. Undergraduate (U) or Graduate (G) 8. Full-time (FT) or Part-time (PT)  \
# 0                                    U                                  FT
# 1                                    U                                  FT
# 2                                    U                                  FT
# 3                                    U                                  FT
# 4                                    U                                  FT
#
#   9. At-Home or Not-at-Home 9. 5 or More Undergrads/Unit (Y/N)  \
# 0                   Private                                  N
# 1                      Home                                  N
# 2                   Private                                  N
# 3                   Private                                  N
# 4                   Private                                  N
#
#                 University       Year
# 0  Northeastern University  2020-2021
# 1  Northeastern University  2020-2021
# 2  Northeastern University  2020-2021
# 3  Northeastern University  2020-2021
# 4  Northeastern University  2020-2021
# Northeastern data successfully saved to Northeastern_Processed_Debug.xlsx

# %%
import pandas as pd
import re

# File path for Northeastern University
northeastern_file_path = '/content/unzipped_files/2020-2021 School Year Reports/Northeastern University.xlsx'

# Desired column names
desired_columns = [
    "6a. Street #",
    "6b. Street Name",
    "6c. Street Suffix",
    "6d. Unit #",
    "6e. Zip",
    "7. Undergraduate (U) or Graduate (G)",
    "8. Full-time (FT) or Part-time (PT)",
    "9. At-Home or Not-at-Home",
    "9. 5 or More Undergrads/Unit (Y/N)",
    "University",
    "Year"
]

# Function to split address into components (Street Name and Suffix separated)
def split_address(address):
    # Modify the regex to capture cases like "Temple Street" or "Main St"
    match = re.match(r"(\d+)\s+([A-Za-z\s]+)\s+([A-Za-z]+)(?:\s*,?\s*(?:Unit\s|Apt\s|#)?(\w+))?", address)
    if match:
        street_number = match.group(1)
        street_name = match.group(2).strip()  # Handles multi-word street names
        street_suffix = match.group(3)  # Street suffix such as Street, Ave, etc.
        unit_number = match.group(4) if match.group(4) else ''
    else:
        street_number, street_name, street_suffix, unit_number = '', '', '', ''

    return street_number, street_name, street_suffix, unit_number

# Load the Northeastern University file
print("Checking Northeastern University file...")

try:
    northeastern_sheets = pd.ExcelFile(northeastern_file_path).sheet_names
    print(f"Available sheets: {northeastern_sheets}")

    northeastern_sheet_name = [name for name in northeastern_sheets if 'Student Addresses' in name][0]
    print(f"Using sheet: {northeastern_sheet_name}")

    # Load Northeastern University data
    df_northeastern = pd.read_excel(northeastern_file_path, sheet_name=northeastern_sheet_name, skiprows=3)
    print(f"Loaded Northeastern data with shape: {df_northeastern.shape}")

    # Split the address into its components
    df_northeastern['6a. Street #'], df_northeastern['6b. Street Name'], df_northeastern['6c. Street Suffix'], df_northeastern['6d. Unit #'] = zip(*df_northeastern.iloc[:, 0].map(split_address))

    # Fill in remaining columns
    df_northeastern['6e. Zip'] = df_northeastern.iloc[:, 2]  # Zip code column
    df_northeastern['7. Undergraduate (U) or Graduate (G)'] = df_northeastern.iloc[:, 3].apply(lambda x: 'U' if 'Undergraduate' in x else 'G')
    df_northeastern['8. Full-time (FT) or Part-time (PT)'] = df_northeastern.iloc[:, 4].apply(lambda x: 'FT' if 'Full Time' in x else 'PT')

    # Adjust '9. At-Home or Not-at-Home' with your desired values for Northeastern University
    at_home_values = ['Private', 'Home', 'Private', 'Private', 'Private', 'Private', 'Private']
    repeated_at_home_values = (at_home_values * (len(df_northeastern) // len(at_home_values) + 1))[:len(df_northeastern)]
    df_northeastern['9. At-Home or Not-at-Home'] = repeated_at_home_values

    df_northeastern['9. 5 or More Undergrads/Unit (Y/N)'] = 'N'  # Defaulting to 'N'
    df_northeastern['University'] = 'Northeastern University'
    df_northeastern['Year'] = '2020-2021'

    # Reorder columns according to the desired format
    df_northeastern = df_northeastern[desired_columns]

    print("First 5 rows after processing Northeastern University data:")
    print(df_northeastern.head())

    # Save the Northeastern data to a new file for debugging
    output_file = '3-Northeastern_Processed_Debug.xlsx'
    df_northeastern.to_excel(output_file, index=False)
    print(f"Northeastern data successfully saved to {output_file}")

except Exception as e:
    print(f"Error processing Northeastern University: {e}")
# Out:
# Checking Northeastern University file...
# Available sheets: ['Summary Stats', 'Student Addresses', 'University Bldgs', 'Dorm-Bed Data', 'Definitions', 'Student Housing Instructions', 'Building Instructions', 'Contact Info']
# Using sheet: Student Addresses
# Loaded Northeastern data with shape: (11171, 8)
# First 5 rows after processing Northeastern University data:
#   6a. Street # 6b. Street Name 6c. Street Suffix 6d. Unit #  6e. Zip  \
# 0           60        Hillside                St                2120
# 1           26          Sussex                St                2120
# 2          614        Columbus               Ave          2     2120
# 3           21            Dorr            Street          C     2119
# 4            5        Iroquois            Street          2     2120
#
#   7. Undergraduate (U) or Graduate (G) 8. Full-time (FT) or Part-time (PT)  \
# 0                                    U                                  FT
# 1                                    U                                  FT
# 2                                    U                                  FT
# 3                                    U                                  FT
# 4                                    U                                  FT
#
#   9. At-Home or Not-at-Home 9. 5 or More Undergrads/Unit (Y/N)  \
# 0                   Private                                  N
# 1                      Home                                  N
# 2                   Private                                  N
# 3                   Private                                  N
# 4                   Private                                  N
#
#                 University       Year
# 0  Northeastern University  2020-2021
# 1  Northeastern University  2020-2021
# 2  Northeastern University  2020-2021
# 3  Northeastern University  2020-2021
# 4  Northeastern University  2020-2021
# Northeastern data successfully saved to 3-Northeastern_Processed_Debug.xlsx

# %%
import pandas as pd
import re

# File path for Northeastern University
northeastern_file_path = '/content/unzipped_files/2021-2022 School Year Reports/Northeastern University.xlsx'

# Desired column names
desired_columns = [
    "6a. Street #",
    "6b. Street Name",
    "6c. Street Suffix",
    "6d. Unit #",
    "6e. Zip",
    "7. Undergraduate (U) or Graduate (G)",
    "8. Full-time (FT) or Part-time (PT)",
    "9. At-Home or Not-at-Home",
    "9. 5 or More Undergrads/Unit (Y/N)",
    "University",
    "Year"
]

# Function to split address into components (Street Name and Suffix separated)
def split_address(address):
    # Modify the regex to capture cases like "Temple Street" or "Main St"
    match = re.match(r"(\d+)\s+([A-Za-z\s]+)\s+([A-Za-z]+)(?:\s*,?\s*(?:Unit\s|Apt\s|#)?(\w+))?", address)
    if match:
        street_number = match.group(1)
        street_name = match.group(2).strip()  # Handles multi-word street names
        street_suffix = match.group(3)  # Street suffix such as Street, Ave, etc.
        unit_number = match.group(4) if match.group(4) else ''
    else:
        street_number, street_name, street_suffix, unit_number = '', '', '', ''

    return street_number, street_name, street_suffix, unit_number

# Load the Northeastern University file
print("Checking Northeastern University file...")

try:
    northeastern_sheets = pd.ExcelFile(northeastern_file_path).sheet_names
    print(f"Available sheets: {northeastern_sheets}")

    northeastern_sheet_name = [name for name in northeastern_sheets if 'Student Addresses' in name][0]
    print(f"Using sheet: {northeastern_sheet_name}")

    # Load Northeastern University data
    df_northeastern = pd.read_excel(northeastern_file_path, sheet_name=northeastern_sheet_name, skiprows=3)
    print(f"Loaded Northeastern data with shape: {df_northeastern.shape}")

    # Split the address into its components
    df_northeastern['6a. Street #'], df_northeastern['6b. Street Name'], df_northeastern['6c. Street Suffix'], df_northeastern['6d. Unit #'] = zip(*df_northeastern.iloc[:, 0].map(split_address))

    # Fill in remaining columns
    df_northeastern['6e. Zip'] = df_northeastern.iloc[:, 2]  # Zip code column
    df_northeastern['7. Undergraduate (U) or Graduate (G)'] = df_northeastern.iloc[:, 3].apply(lambda x: 'U' if 'Undergraduate' in x else 'G')
    df_northeastern['8. Full-time (FT) or Part-time (PT)'] = df_northeastern.iloc[:, 4].apply(lambda x: 'FT' if 'Full Time' in x else 'PT')

    # Adjust '9. At-Home or Not-at-Home' with your desired values for Northeastern University
    at_home_values = ['Private', 'Home', 'Private', 'Private', 'Private', 'Private', 'Private']
    repeated_at_home_values = (at_home_values * (len(df_northeastern) // len(at_home_values) + 1))[:len(df_northeastern)]
    df_northeastern['9. At-Home or Not-at-Home'] = repeated_at_home_values

    df_northeastern['9. 5 or More Undergrads/Unit (Y/N)'] = 'N'  # Defaulting to 'N'
    df_northeastern['University'] = 'Northeastern University'
    df_northeastern['Year'] = '2021-2022'

    # Reorder columns according to the desired format
    df_northeastern = df_northeastern[desired_columns]

    print("First 5 rows after processing Northeastern University data:")
    print(df_northeastern.head())

    # Save the Northeastern data to a new file for debugging
    output_file = '4-Northeastern_Processed_Debug.xlsx'
    df_northeastern.to_excel(output_file, index=False)
    print(f"Northeastern data successfully saved to {output_file}")

except Exception as e:
    print(f"Error processing Northeastern University: {e}")
# Out:
# Checking Northeastern University file...
# Available sheets: ['Summary Stats', 'Student Addresses', 'University Bldgs', 'Dorm-Bed Data', 'Definitions', 'Student Housing Instructions', 'Building Instructions', 'Contact Info']
# Using sheet: Student Addresses
# Loaded Northeastern data with shape: (10705, 8)
# First 5 rows after processing Northeastern University data:
#   6a. Street # 6b. Street Name 6c. Street Suffix 6d. Unit #  6e. Zip  \
# 0          124          Temple            Street                2132
# 1                                                               2119
# 2            8         Shepard                St                2135
# 3           11     Christopher            Street          3     2122
# 4          191            Park             Drive          4     2215
#
#   7. Undergraduate (U) or Graduate (G) 8. Full-time (FT) or Part-time (PT)  \
# 0                                    U                                  FT
# 1                                    U                                  FT
# 2                                    U                                  FT
# 3                                    U                                  FT
# 4                                    G                                  PT
#
#   9. At-Home or Not-at-Home 9. 5 or More Undergrads/Unit (Y/N)  \
# 0                   Private                                  N
# 1                      Home                                  N
# 2                   Private                                  N
# 3                   Private                                  N
# 4                   Private                                  N
#
#                 University       Year
# 0  Northeastern University  2021-2022
# 1  Northeastern University  2021-2022
# 2  Northeastern University  2021-2022
# 3  Northeastern University  2021-2022
# 4  Northeastern University  2021-2022
# Northeastern data successfully saved to 4-Northeastern_Processed_Debug.xlsx

# %%
import pandas as pd
import os

file_paths = [
    '/content/unzipped_files/2021-2022 School Year Reports/Bay State College.xlsx',
    '/content/unzipped_files/2021-2022 School Year Reports/Berklee College of Music-Boston Conservatory.xlsx',
    '/content/unzipped_files/2021-2022 School Year Reports/Boston Architectural College.xlsx',
    '/content/unzipped_files/2021-2022 School Year Reports/Boston Baptist College.xlsx',
    '/content/unzipped_files/2021-2022 School Year Reports/Boston College WCAS.xlsx',
    '/content/unzipped_files/2021-2022 School Year Reports/Boston College.xlsx',
    '/content/unzipped_files/2021-2022 School Year Reports/Boston University.xlsx',
    '/content/unzipped_files/2021-2022 School Year Reports/Emerson College.xlsx',
    '/content/unzipped_files/2021-2022 School Year Reports/Emmanuel College.xlsx',
    '/content/unzipped_files/2021-2022 School Year Reports/Fisher College.xlsx',
    '/content/unzipped_files/2021-2022 School Year Reports/Franklin Institute of Technology.xlsx',
    '/content/unzipped_files/2021-2022 School Year Reports/Harvard University.xlsx',
    '/content/unzipped_files/2021-2022 School Year Reports/MGH Institute of Health Professions.xlsx',
    '/content/unzipped_files/2021-2022 School Year Reports/Massachusetts College of Art and Design.xlsx',
    '/content/unzipped_files/2021-2022 School Year Reports/Massachusetts Institute of Technology.xlsx',
    '/content/unzipped_files/2021-2022 School Year Reports/New England College of Optometry.xlsx',
    '/content/unzipped_files/2021-2022 School Year Reports/Northeastern University.xlsx',
    '/content/unzipped_files/2021-2022 School Year Reports/SHOWA Institute Boston.xlsx',
    '/content/unzipped_files/2021-2022 School Year Reports/Sattler College.xlsx',
    '/content/unzipped_files/2021-2022 School Year Reports/Simmons University.xlsx',
    '/content/unzipped_files/2021-2022 School Year Reports/St. John\'s Seminary.xlsx',
    '/content/unzipped_files/2021-2022 School Year Reports/Suffolk University.xlsx',
    '/content/unzipped_files/2021-2022 School Year Reports/Tufts University.xlsx',
    '/content/unzipped_files/2021-2022 School Year Reports/University of Massachusetts-Boston.xlsx',
    '/content/unzipped_files/2021-2022 School Year Reports/Urban College of Boston.xlsx',
    '/content/unzipped_files/2021-2022 School Year Reports/Wentworth Institute of Technology.xlsx',
]
all_data = []

desired_columns = [
    "6a. Street #",
    "6b. Street Name",
    "6c. Street Suffix",
    "6d. Unit #",
    "6e. Zip",
    "7. Undergraduate (U) or Graduate (G)",
    "8. Full-time (FT) or Part-time (PT)",
    "9. At-Home or Not-at-Home",
    "9. 5 or More Undergrads/Unit (Y/N)",
    "University",
    "Year"
]

for file_path in file_paths:
    file_name = os.path.basename(file_path).replace('.xlsx', '')

    try:
        df = pd.read_excel(file_path, sheet_name='Student Addresses', skiprows=2)

        if len(df.columns) >= 8:
            df = df.iloc[:, :8]

            df.columns = [
                "6a. Street #",
                "6b. Street Name",
                "6c. Street Suffix",
                "6d. Unit #",
                "6e. Zip",
                "7. Undergraduate (U) or Graduate (G)",
                "8. Full-time (FT) or Part-time (PT)",
                "9. At-Home or Not-at-Home"
            ]

            if '9. 5 or More Undergrads/Unit (Y/N)' not in df.columns:
                df['9. 5 or More Undergrads/Unit (Y/N)'] = 'N/A'

            df['University'] = file_name
            df['Year'] = '2023-2024'

            all_data.append(df)
        else:
            print(f"File {file_name} skipped due to insufficient columns.")

    except Exception as e:
        print(f"Error processing file {file_name}: {e}")

if all_data:
    combined_df = pd.concat(all_data, ignore_index=True)

    combined_df = combined_df[desired_columns]

    output_file = '21-22.xlsx'
    combined_df.to_excel(output_file, index=False)

    print(f"Data successfully saved to {output_file}")
else:
    print("No valid data to combine.")
# Out:
# File MGH Institute of Health Professions skipped due to insufficient columns.
# /usr/local/lib/python3.10/dist-packages/openpyxl/worksheet/_reader.py:329: UserWarning: Unknown extension is not supported and will be removed
#   warn(msg)
# File SHOWA Institute Boston skipped due to insufficient columns.
# File Sattler College skipped due to insufficient columns.
# Data successfully saved to 21-22.xlsx

# %%
import pandas as pd

# Paths to the Excel files
file_2020_2021 = '2-FINAL-2020_2021.xlsx'
file_2021_2022 = 'FINAL-2021_2022.xlsx'

# Read both Excel files
try:
    df_2020_2021 = pd.read_excel(file_2020_2021)
    df_2021_2022 = pd.read_excel(file_2021_2022)

    # Check row counts
    print(f"Rows in 2020-2021 DataFrame: {len(df_2020_2021)}")
    print(f"Rows in 2021-2022 DataFrame: {len(df_2021_2022)}")

    # Combine the two dataframes
    combined_df = pd.concat([df_2020_2021, df_2021_2022], ignore_index=True)

    # Check combined row count
    print(f"Rows in Combined DataFrame: {len(combined_df)}")

    # Save the combined dataframe to a CSV file
    output_csv_file = 'Combined_FINAL_2020_2022.csv'
    combined_df.to_csv(output_csv_file, index=False)

    print(f"Data successfully saved to {output_csv_file}")

except Exception as e:
    print(f"Error combining files: {e}")
# Out:
# Rows in 2020-2021 DataFrame: 33735
# Rows in 2021-2022 DataFrame: 34976
# Rows in Combined DataFrame: 68711
# Data successfully saved to Combined_FINAL_2020_2022.csv
